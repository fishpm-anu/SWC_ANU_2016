# %%
import pandas as dp

# %%
surveys_df = dp.read_csv('surveys.csv')

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveys_species = surveys_df['species_id']

# %%
surveys_df[['species_id','plot_id']].head()
# Out:
#   species_id  plot_id
# 0         NL        2
# 1         NL        3
# 2         DM        2
# 3         DM        7
# 4         DM        3

# %%
surveys_df.year.head()
# Out:
# 0    1977
# 1    1977
# 2    1977
# 3    1977
# 4    1977
# Name: year, dtype: int64

# %%
surveys_df[(surveys_df.year >= 1980)&(surveys_df.year <= 1985)].head()
# Out:
#       record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 2270       2271      1   15  1980        8         DO   M             35.0
# 2271       2272      1   15  1980       11         PF   F             16.0
# 2272       2273      1   15  1980       18         DM   F             34.0
# 2273       2274      1   15  1980       11         DM   M             38.0
# 2274       2275      1   15  1980        8         DO   F             33.0
#
#       weight
# 2270    53.0
# 2271    10.0
# 2272    33.0
# 2273    37.0
# 2274    29.0

# %%
surveys_df[(surveys_df.year == 1999)&(surveys_df.weight <= 8)]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 29082      29083      1   16  1999       21         RM   M             16.0
# 29196      29197      2   20  1999       18         RM   M             18.0
# 29421      29422      3   15  1999       16         RM   M             15.0
# 29903      29904     10   10  1999        4         PP   M             20.0
# 29905      29906     10   10  1999        4         PP   M             21.0
#
#        weight
# 29082     8.0
# 29196     8.0
# 29421     8.0
# 29903     7.0
# 29905     4.0

# %%
surveys_df[surveys_df['species_id'].isin(['RM','PP'])].head()
# Out:
#      record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 17          18      7   16  1977        2         PP   M             22.0
# 28          29      7   17  1977       11         PP   M              NaN
# 48          49      7   18  1977       12         PP   F             17.0
# 88          89      8   20  1977       12         PP   F             20.0
# 107        108      8   20  1977       11         PP   M             21.0
#
#      weight
# 17      NaN
# 28      NaN
# 48      NaN
# 88     15.0
# 107     NaN

# %%
surveys_df[~surveys_df['sex'].isin(['M','F'])].count()
# Out:
# record_id          2511
# month              2511
# day                2511
# year               2511
# plot_id            2511
# species_id         1748
# sex                   0
# hindfoot_length      68
# weight              101
# dtype: int64

# %%
dp.isnull(surveys_df)
# Out:
#       record_id  month    day   year plot_id species_id    sex  \
# 0         False  False  False  False   False      False  False
# 1         False  False  False  False   False      False  False
# 2         False  False  False  False   False      False  False
# 3         False  False  False  False   False      False  False
# 4         False  False  False  False   False      False  False
# 5         False  False  False  False   False      False  False
# 6         False  False  False  False   False      False  False
# 7         False  False  False  False   False      False  False
# 8         False  False  False  False   False      False  False
# 9         False  False  False  False   False      False  False
# 10        False  False  False  False   False      False  False
# 11        False  False  False  False   False      False  False
# 12        False  False  False  False   False      False  False
# 13        False  False  False  False   False      False   True
# ...

# %%
surveys_df[(dp.isnull(surveys_df).any(axis=1))]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
newsex_df = surveys_df[~surveys_df['sex'].isin(['M','F'])]

# %%
newsex_df.loc[:,'sex'] = 'x'

# %%
newsex_df['sex'].head()
# Out:
# 13    x
# 18    x
# 33    x
# 56    x
# 76    x
# Name: sex, dtype: object

# %%
newsex_df.head()
# Out:
#    record_id month day  year plot_id species_id sex hindfoot_length weight
# 13        14     7  16  1977       8         DM  ax             NaN    NaN
# 18        19     7  16  1977       4         PF  ax             NaN    NaN
# 33        34     7  17  1977      17         DM  ax             NaN    NaN
# 56        57     7  18  1977      22         DM  ax             NaN    NaN
# 76        77     8  19  1977       4         SS  ax             NaN    NaN

# %%
MF_df = surveys_df[surveys_df['sex'].isin(['M','F']) & (surveys_df.weight > 0)]

# %%
mfsmall_df = MF_df.head()

# %%
mfsmall_df.plot.bar(x='weight')

# %%
species_df = dp.read_csv("species.csv")

# %%
surveyssub = species_df.head()

# %%
surveysublast10 = species_df.tail(10)

# %%
surveysublast10 = surveysublast10.reset_index(drop=True)

# %%
vertical_stack.to_csv('out.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-b0ff3fdf5546> in <module>()
# ----> 1 vertical_stack.to_csv('out.csv')
#
# NameError: name 'vertical_stack' is not defined

# %%
d_frame8082 = surveys_df[surveys_df['year'].isin([1980,1982])]

# %%
# Out:
#       record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 2270       2271      1   15  1980        8         DO   M             35.0
# 2271       2272      1   15  1980       11         PF   F             16.0
# 2272       2273      1   15  1980       18         DM   F             34.0
# 2273       2274      1   15  1980       11         DM   M             38.0
# 2274       2275      1   15  1980        8         DO   F             33.0
# 2275       2276      1   15  1980       11         DS   M             47.0
# 2276       2277      1   15  1980        8         PF   M             15.0
# 2277       2278      1   15  1980        9         OT   M             21.0
# 2278       2279      1   15  1980       11         DM   F             36.0
# 2279       2280      1   15  1980       21         OT   F             20.0
# 2280       2281      1   15  1980       11         OL   M             20.0
# ...

# %%
d_frame8082.to_csv('data80-82.csv')

# %%
surveySub = surveys_df.head(10)
speciesSub = species_df.head(10)

# %%
merged_inner = dp.merge(left=species_df,right=surveyssub,
                        left_on='species_id', right_on='species_id')

# %%
import pandas as pd

# %%
surveySub = surveys_df.head(10)
surveySubLast10 = surveys_df[-11:-1]
surveySubLast10=surveySubLast10.reset_index(drop=True)

# %%
surveySub = surveys_df.head(100)
speciesSub = species_df.head(12)

# %%
merged_inner = pd.merge(left=surveySub,right=speciesSub, left_on='species_id', right_on='species_id')

# %%
merged_inner
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           3      7   16  1977        2         DM    F             37.0
# 1           4      7   16  1977        7         DM    M             36.0
# 2           5      7   16  1977        3         DM    M             35.0
# 3           8      7   16  1977        1         DM    M             37.0
# 4           9      7   16  1977        1         DM    F             34.0
# 5          12      7   16  1977        7         DM    M             38.0
# 6          13      7   16  1977        3         DM    M             35.0
# 7          14      7   16  1977        8         DM  NaN              NaN
# 8          15      7   16  1977        6         DM    F             36.0
# 9          16      7   16  1977        4         DM    F             36.0
# 10         21      7   17  1977       14         DM    F             34.0
# 11         23      7   17  1977       13         DM    M             36.0
# ...

# %%
merged_left = pd.merge(left=surveySub,right=speciesSub, how='left', left_on='species_id', right_on='species_id')

# %%
merged_left
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10         11      7   16  1977        5         DS    F             53.0
# 11         12      7   16  1977        7         DM    M             38.0
# ...

# %%
sex_df.groupby('sex')['weight'].mean().plot(kind='bar’)
# Out:
#   File "<ipython-input-139-9c991d23d9e5>", line 1
#     sex_df.groupby('sex')['weight'].mean().plot(kind='bar’)
#                                                            ^
# SyntaxError: EOL while scanning string literal
